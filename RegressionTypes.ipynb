# %%
import warnings

# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('BlackFridayTrainNew.csv')

# %%
test_data = pd.read_csv('BlackFridayTestNew.csv')

# %%
train_data
# Out:
#         Unnamed: 0  User_ID  Product_ID  Gender  Age  Occupation  \
# 0                0  1000001       69042       0    0          10
# 1                1  1000001      248942       0    0          10
# 2                2  1000001       87842       0    0          10
# 3                3  1000001       85442       0    0          10
# 4                4  1000002      285442       1    6          16
# 5                5  1000003      193542       1    2          15
# 6                6  1000004      184942       1    4           7
# 7                7  1000004      346142       1    4           7
# 8                8  1000004       97242       1    4           7
# 9                9  1000005      274942       1    2          20
# 10              10  1000005      251242       1    2          20
# 11              11  1000005       14542       1    2          20
# 12              12  1000005       31342       1    2          20
# ...

# %%
train_data = train_data.drop(['Unnamed: 0'], axis=1)

# %%
train_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001       69042       0    0          10              0
# 1       1000001      248942       0    0          10              0
# 2       1000001       87842       0    0          10              0
# 3       1000001       85442       0    0          10              0
# 4       1000002      285442       1    6          16              2
# 5       1000003      193542       1    2          15              0
# 6       1000004      184942       1    4           7              1
# 7       1000004      346142       1    4           7              1
# 8       1000004       97242       1    4           7              1
# 9       1000005      274942       1    2          20              0
# 10      1000005      251242       1    2          20              0
# 11      1000005       14542       1    2          20              0
# 12      1000005       31342       1    2          20              0
# ...

# %%
train_data.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2              int64
# Product_Category_3              int64
# Purchase                        int64
# Category_Count                  int64
# Product_Score                 float64
# User_Score                    float64
# dtype: object

# %%
test_data
# Out:
#         Unnamed: 0  User_ID  Product_ID  Gender  Age  Occupation  \
# 0                0  1000004      128942       1    4           7
# 1                1  1000009      113442       1    2          17
# 2                2  1000010      288442       0    3           1
# 3                3  1000010      145342       0    3           1
# 4                4  1000011       53842       0    2           1
# 5                5  1000013      350442       1    4           1
# 6                6  1000013      155442       1    4           1
# 7                7  1000013       94542       1    4           1
# 8                8  1000015      161842       1    2           7
# 9                9  1000022       67942       1    1          15
# 10              10  1000026       46742       1    2           7
# 11              11  1000026       40042       1    2           7
# 12              12  1000026      196542       1    2           7
# ...

# %%
test_data = test_data.drop(['Unnamed: 0'], axis=1)

# %%
test_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
x_train = train_data.iloc[:, 0:14]

# %%
x_train
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001       69042       0    0          10              0
# 1       1000001      248942       0    0          10              0
# 2       1000001       87842       0    0          10              0
# 3       1000001       85442       0    0          10              0
# 4       1000002      285442       1    6          16              2
# 5       1000003      193542       1    2          15              0
# 6       1000004      184942       1    4           7              1
# 7       1000004      346142       1    4           7              1
# 8       1000004       97242       1    4           7              1
# 9       1000005      274942       1    2          20              0
# 10      1000005      251242       1    2          20              0
# 11      1000005       14542       1    2          20              0
# 12      1000005       31342       1    2          20              0
# ...

# %%
y_train = train_data.iloc[:, 14]

# %%
y_train
# Out:
# 0         0.034113
# 1         0.034113
# 2         0.034113
# 3         0.034113
# 4         0.075049
# 5         0.028265
# 6         0.013645
# 7         0.013645
# 8         0.013645
# 9         0.103314
# 10        0.103314
# 11        0.103314
# 12        0.103314
# 13        0.103314
# 14        0.045809
# 15        0.045809
# 16        0.045809
# 17        0.045809
# 18        0.016569
# 19        0.075049
# 20        0.075049
# 21        0.075049
# 22        0.075049
# 23        0.075049
# 24        0.075049
# 25        0.056530
# 26        0.056530
# 27        0.056530
# 28        0.056530
# 29        0.217349
#             ...
# 550038    0.100390
# 550039    0.320663
# 550040    0.028265
# 550041    0.273879
# 550042    0.177388
# 550043    0.146199
# 550044    0.033138
# 550045    0.048733
# 550046    0.067251
# 550047    0.031189
# 550048    0.172515
# 550049    0.102339
# 550050    0.015595
# 550051    0.073099
# 550052    0.491228
# 550053    0.017544
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# test_data = test_data.drop(['Purchase'], axis=1)

# %%
regr = RandomForestRegressor(n_estimators=100, max_depth=7, n_jobs=-1)
regr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=7,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
result = regr.predict(test_data)
result
# Out:
# array([0.2395012 , 0.08406741, 0.22235675, ..., 0.31011752, 0.11949431,
#        0.07212476])

# %%
test_data['Purchase'] = result

# %%
finalSolution = test_data[['User_ID', 'Product_ID', 'Purchase']]

# %%
finalSolution
# Out:
#         User_ID  Product_ID  Purchase
# 0       1000004      128942  0.239501
# 1       1000009      113442  0.084067
# 2       1000010      288442  0.222357
# 3       1000010      145342  0.222357
# 4       1000011       53842  0.078462
# 5       1000013      350442  0.089442
# 6       1000013      155442  0.089442
# 7       1000013       94542  0.089442
# 8       1000015      161842  0.234202
# 9       1000022       67942  0.160192
# 10      1000026       46742  0.238231
# 11      1000026       40042  0.238231
# 12      1000026      196542  0.238231
# 13      1000026        4542  0.238231
# 14      1000028      159542  0.078099
# 15      1000029      111542  0.073522
# 16      1000033      121042  0.166023
# 17      1000033      344442  0.166023
# 18      1000034      265242  0.221415
# 19      1000035       96642  0.089442
# 20      1000036      303042  0.239094
# 21      1000036       59642  0.239094
# 22      1000042       30842  0.073522
# 23      1000045      346442  0.209117
# ...

# %%
finalSolution.to_csv('RandomForest.csv')

# %%
finalSolution['Purchase'] = result
# Out:
# /Users/suhaniladani/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
finalSolution
# Out:
#         User_ID  Product_ID  Purchase
# 0       1000004      128942  0.239501
# 1       1000009      113442  0.084067
# 2       1000010      288442  0.222357
# 3       1000010      145342  0.222357
# 4       1000011       53842  0.078462
# 5       1000013      350442  0.089442
# 6       1000013      155442  0.089442
# 7       1000013       94542  0.089442
# 8       1000015      161842  0.234202
# 9       1000022       67942  0.160192
# 10      1000026       46742  0.238231
# 11      1000026       40042  0.238231
# 12      1000026      196542  0.238231
# 13      1000026        4542  0.238231
# 14      1000028      159542  0.078099
# 15      1000029      111542  0.073522
# 16      1000033      121042  0.166023
# 17      1000033      344442  0.166023
# 18      1000034      265242  0.221415
# 19      1000035       96642  0.089442
# 20      1000036      303042  0.239094
# 21      1000036       59642  0.239094
# 22      1000042       30842  0.073522
# 23      1000045      346442  0.209117
# ...

# %%
finalSolution.to_csv('Result.csv')

# %%
from sklearn import linear_model

# %%
lm = linear_model.LinearRegression()

# %%
model = lm.fit(x_train, y_train)

# %%
test_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
test_data = test_data.drop(['Purchase'], axis=1)

# %%
prediction = lm.predict(test_data)

# %%
prediction
# Out:
# array([0.27773905, 0.14971595, 0.2064054 , ..., 0.18488663, 0.09479551,
#        0.21886811])

# %%
test_data.size
# Out:
# 3270386

# %%
prediction.size
# Out:
# 233599

# %%
linear_model_solution = test_data[['User_ID', 'Product_ID']]

# %%
linear_model_solution['Purchase'] = prediction
# Out:
# /Users/suhaniladani/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
linear_model_solution
# Out:
#         User_ID  Product_ID  Purchase
# 0       1000004      128942  0.277739
# 1       1000009      113442  0.149716
# 2       1000010      288442  0.206405
# 3       1000010      145342  0.215402
# 4       1000011       53842  0.115533
# 5       1000013      350442  0.145973
# 6       1000013      155442  0.154592
# 7       1000013       94542  0.158326
# 8       1000015      161842  0.356478
# 9       1000022       67942  0.362386
# 10      1000026       46742  0.253929
# 11      1000026       40042  0.250831
# 12      1000026      196542  0.240787
# 13      1000026        4542  0.250771
# 14      1000028      159542  0.113150
# 15      1000029      111542  0.145652
# 16      1000033      121042  0.346861
# 17      1000033      344442  0.343927
# 18      1000034      265242  0.333363
# 19      1000035       96642  0.154879
# 20      1000036      303042  0.232418
# 21      1000036       59642  0.247510
# 22      1000042       30842  0.151963
# 23      1000045      346442  0.329943
# ...

# %%
linear_model_solution.to_csv('LinearRegressionResult.csv')

# %%
train_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001       69042       0    0          10              0
# 1       1000001      248942       0    0          10              0
# 2       1000001       87842       0    0          10              0
# 3       1000001       85442       0    0          10              0
# 4       1000002      285442       1    6          16              2
# 5       1000003      193542       1    2          15              0
# 6       1000004      184942       1    4           7              1
# 7       1000004      346142       1    4           7              1
# 8       1000004       97242       1    4           7              1
# 9       1000005      274942       1    2          20              0
# 10      1000005      251242       1    2          20              0
# 11      1000005       14542       1    2          20              0
# 12      1000005       31342       1    2          20              0
# ...

# %%
train_data.corr()
# Out:
#                              User_ID  Product_ID    Gender       Age  \
# User_ID                     1.000000   -0.017619 -0.033474  0.032698
# Product_ID                 -0.017619    1.000000  0.021084  0.028892
# Gender                     -0.033474    0.021084  1.000000 -0.004262
# Age                         0.032698    0.028892 -0.004262  1.000000
# Occupation                 -0.023971    0.009344  0.117291  0.091463
# City_Category               0.022859    0.010162 -0.004515  0.123079
# Stay_In_Current_City_Years -0.030737   -0.003162  0.014660 -0.004712
# Marital_Status              0.020443    0.013194 -0.011603  0.311738
# Product_Category_1          0.003825    0.090193 -0.045594  0.061197
# Product_Category_2          0.003896   -0.090600 -0.000954  0.018770
# Product_Category_3          0.003605   -0.144360  0.036146 -0.007422
# Purchase                    0.004716   -0.103961  0.060346  0.015839
# Category_Count              0.004270   -0.183299  0.026808 -0.021246
# ...

# %%
from sklearn.linear_model import Ridge

# %%
ridgeReg = Ridge(alpha=0.05, normalize=True)

# %%
ridgeReg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.05, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=True, random_state=None, solver='auto', tol=0.001)

# %%
ridgePrediction = ridgeReg.predict(test_data)

# %%
ridgePrediction
# Out:
# array([0.27574656, 0.15459212, 0.20809418, ..., 0.18711657, 0.10134825,
#        0.21936484])

# %%
test_data['Purchase'] = ridgePrediction

# %%
test_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
test_data.to_csv('RidgeResult.csv')

# %%
result_data = test_data[['User_ID', 'Product_ID', 'Purchase']]

# %%
result_data
# Out:
#         User_ID  Product_ID  Purchase
# 0       1000004      128942  0.275747
# 1       1000009      113442  0.154592
# 2       1000010      288442  0.208094
# 3       1000010      145342  0.216559
# 4       1000011       53842  0.122062
# 5       1000013      350442  0.150548
# 6       1000013      155442  0.158690
# 7       1000013       94542  0.162129
# 8       1000015      161842  0.352013
# 9       1000022       67942  0.357278
# 10      1000026       46742  0.253330
# 11      1000026       40042  0.250558
# 12      1000026      196542  0.241284
# 13      1000026        4542  0.250520
# 14      1000028      159542  0.119941
# 15      1000029      111542  0.150473
# 16      1000033      121042  0.341645
# 17      1000033      344442  0.339144
# 18      1000034      265242  0.329613
# 19      1000035       96642  0.158666
# 20      1000036      303042  0.233302
# 21      1000036       59642  0.247643
# 22      1000042       30842  0.156601
# 23      1000045      346442  0.325679
# ...

# %%
result_data.to_csv('RidgeResult.csv')

# %%
from sklearn.linear_model import ElasticNet

# %%
eReg = ElasticNet(alpha=1, l1_ratio=0.5, normalize=False)

# %%
eReg.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
test_data.drop(['Purchase'], axis=1)
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
test_data = test_data.drop(['Purchase'], axis=1)

# %%
elastic_result = eReg.predict(test_data)

# %%
elastic_result
# Out:
# array([0.250182  , 0.25062054, 0.24549549, ..., 0.23477007, 0.23205109,
#        0.22642837])

# %%
test_data['Purchase'] = elastic_result

# %%
test_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
test_data.to_csv('ElasticNetResult.csv')

# %%
elastic_csv = test_data[['User_ID', 'Product_ID', 'Purchase']]

# %%
elastic_csv
# Out:
#         User_ID  Product_ID  Purchase
# 0       1000004      128942  0.250182
# 1       1000009      113442  0.250621
# 2       1000010      288442  0.245495
# 3       1000010      145342  0.249684
# 4       1000011       53842  0.252356
# 5       1000013      350442  0.243669
# 6       1000013      155442  0.249376
# 7       1000013       94542  0.251159
# 8       1000015      161842  0.249183
# 9       1000022       67942  0.251913
# 10      1000026       46742  0.252518
# 11      1000026       40042  0.252721
# 12      1000026      196542  0.248134
# 13      1000026        4542  0.253756
# 14      1000028      159542  0.249211
# 15      1000029      111542  0.250616
# 16      1000033      121042  0.250329
# 17      1000033      344442  0.243784
# 18      1000034      265242  0.246102
# 19      1000035       96642  0.251030
# 20      1000036      303042  0.244993
# 21      1000036       59642  0.252110
# 22      1000042       30842  0.252935
# 23      1000045      346442  0.243689
# ...

# %%
elastic_csv.to_csv('ElasticNetResult.csv')

# %%
test_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000004      128942       1    4           7              1
# 1       1000009      113442       1    2          17              2
# 2       1000010      288442       0    3           1              1
# 3       1000010      145342       0    3           1              1
# 4       1000011       53842       0    2           1              2
# 5       1000013      350442       1    4           1              2
# 6       1000013      155442       1    4           1              2
# 7       1000013       94542       1    4           1              2
# 8       1000015      161842       1    2           7              0
# 9       1000022       67942       1    1          15              0
# 10      1000026       46742       1    2           7              1
# 11      1000026       40042       1    2           7              1
# 12      1000026      196542       1    2           7              1
# ...

# %%
test_data = test_data.drop(['Purchase'], axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor

eTreeReg = ExtraTreesRegressor(n_estimators=6)

eTreeReg.fit(x_train, y_train)

eTreeResult = eTreeReg.predict(test_data)

eTreeResult

test_data['Purchase'] = eTreeResult

e_tree_data = test_data[['User_ID', 'Product_ID', 'Purchase']]

e_tree_data

e_tree_data.to_csv('ExtraTressRegressor.csv')
